# %%
#1 write a program to find the greatest of four numbers entered by the user 
a = int(input("Enter the first number:"))
b = int(input("Enter the second number:"))
c = int(input("Enter the third number:"))
d = int(input("Enter the fourth number:"))

if a > b and a > c and a > d:
    print("a is greatest number")
elif b > c and b > d:
    print("b is greatest number")  
elif c > d:
    print("c is greatest number")
else:
    print("d is greatest number")
# Out:
# d is greatest number

# %%
#2 write a program to find out whether a student has passed or failed if it requires a total of 40% and at least 33% in each subject to pass.
#Assume 3 subjects and take marks as an input from the user 
m1 = int(input("Enter the marks:"))
m2 = int(input("Enter the marks:"))
m3 = int(input("Enter the marks:"))
s = ((m1+m2+m3)*100)/300
if s >= 40 and m1 >= 33 and m2 >= 33 and m3 >= 33:
    print("you are passed", s)
else:
    print("you have failed", s)
# Out:
# you are passed 85.0

# %%
#3 a spam comment is defined as text containing the following keywords:
# "make a lot of money", "by now","subscribe this","click this".write a program to detect these spams
p1 = "Make a lot of money"
p2 = "buy now"
p3 = "subscribe"
p4 = "click this"
message = input("Enter your comment")
if (p1 in message) or (p2 in message) or (p3 in message) or (p4 in message):
    print("this is spam comment")
else: 
    print("not a spam message")
# Out:
# this is spam comment

# %%
#4 write a program to find whether a given username contains less than 10 characters or not 
username = input("Enter the username:")
if len(username)<10:
    print("username is valid")
else:
    print("username is invalid")
# Out:
# username is valid

# %%
#5 write a program which finds out whether a given name is present in a list or not
names = ['Alice', 'Bob', 'Charlie', 'David', 'Eve']
name = input("Enter the name to search: ").strip()

# case-insensitive check
if any(n.lower() == name.lower() for n in names):
    print(f"{name} is present in the list")
else:
    print(f"{name} is not present in the list")
# Out:
# cs is not present in the list

# %%
#6 write a program to calculate the grade of a student from his marks from the following scheme:
# 90 - 100 =>Ex
# 80 - 90=>A 70-80=>B
# 60 - 70=>C
# 50 - 60=>D
# <50 =>F

marks = int(input("Enter your marks:"))
if (marks<=100 and marks>=90):
    grade = "Ex"
elif (marks<90 and marks>=80):
    grade = "A"
elif (marks<80 and marks>=70):
    grade = "B"
elif (marks<70 and marks>=60):
    grade = "C"
elif (marks<60 and marks>=50):
    grade = "D"
elif (marks<50):
    grade = "F"
elif (marks>100 or marks<0):
   print("invalid input")

print("Your grade is ",grade)
# Out:
# Your grade is  A

# %%
#7 write a program to find out whether a post is talking about "Yogesh" or not
post = input("Enter the post: ")
if ("chandan" in post.lower()):
    print("This post is about chandan")
else:
    print("This post is about something else")
# Out:
# This post is about chandan

# %%
#check whether a string palindrome or not 
st = input("Enter your string: ")
print(st)
t = st[::-1]
print(t)
if st==t:
  print("Palindrome")
else:
  print("Not a palindrome")
# Out:
# 55
# 55
# Palindrome

# %%
# Radha is playing with multiple dices according to the number 
# of # dices she wants to decide what she wants to play 
# indoor game or outdoor #and
# if total number of dic is multiple of 3:
# (play outdoor game )
# if total number of dice is multiple of 5:
# "play outdoor games"
# if total number of dice is multiple of 3 or 5 both:
# "no "

# %%
# check whether a number is even or odd
a = int(input("Enter a number: "))
if a% 2 == 0:
    print(" even")
else:
    print(" odd")
# Out:
#  odd
