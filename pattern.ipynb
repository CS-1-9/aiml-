# %%
n = 5 
for i in range(1,n+1):
    print("*"*i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
n = int(input("Enter a number:"))
for i in range(n,0,-1):  
    print("*"*i)
# Out:
# *****
# ****
# ***
# **
# *

# %%
n = 5 
for i in range(1,n+1):
    print(" "*(n-i)+"*"*i)
# Out:
#     *
#    **
#   ***
#  ****
# *****
