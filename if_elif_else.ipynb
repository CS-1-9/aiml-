# %% [markdown]
# if elif else condition

# %%
i = 25
if i>30:
   print("I is greater than 30")
   print("i am in if block")
else:
   print("I is less than 30")
# Out:
# I is less than 30

# %%
#if
#else
#elif
#check whether the number is positive or negative nummber
num = -10
if num>0:
    print("Positive number")
elif num==0:
    print("Number is zero")
else:
    print("Negative number")
# Out:
# Negative number

# %%
#and operator
age = 25
salary = 30000
if age>20 and salary>20000:
    print("Eligible for loan")
else:
    print("Not eligible")
# Out:
# Eligible for loan

# %%
age = int(input("Enter your age:"))
salary = int(input("Enter your salary:"))
if age>25 and salary>20000:
   print("Eligible for loan")
else:
   print("Not eligible")
# Out:
# Not eligible

# %%
#or operation 
marks = int(input("Enter your marks:"))
attendence = int(input("Enter your attendence:"))
if marks>35 or attendence>75:
    print("You are allowed to write your final exams")
else:
    print("You are not allowed to write your final exmas")
# Out:
# You are allowed to write your final exams

# %%
#not operator
is_raining = False
if  not is_raining:
    print("You can go outside")
else:
    print("Take an umbrella")
# Out:
# You can go outside
