# %%
import pyjokes
joke = pyjokes.get_joke()
print(joke)
# Out:
# Why did the QA cross the road? To ruin everyone's day.

# %%
pip install pyttsx3
# Out:
# Requirement already satisfied: pyttsx3 in c:\users\chand\appdata\local\programs\python\python310\lib\site-packages (2.99)
# Requirement already satisfied: pywin32 in c:\users\chand\appdata\local\programs\python\python310\lib\site-packages (from pyttsx3) (311)
# Requirement already satisfied: comtypes in c:\users\chand\appdata\local\programs\python\python310\lib\site-packages (from pyttsx3) (1.4.13)
# Requirement already satisfied: pypiwin32 in c:\users\chand\appdata\local\programs\python\python310\lib\site-packages (from pyttsx3) (223)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\chand\appdata\local\programs\python\python310\lib\site-packages (22.2.2)
# Collecting pip
#   Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#      ---------------------------------------- 1.8/1.8 MB 2.3 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.2.2
#     Uninstalling pip-22.2.2:
#       Successfully uninstalled pip-22.2.2
# Successfully installed pip-25.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts pip.exe, pip3.10.exe and pip3.exe are installed in 'c:\Users\chand\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import pyttsx3
engine = pyttsx3.init()
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[1].id)
# adjust the speed
engine.setProperty('rate', 100)
engine.setProperty('volume',1)
engine.say("Hello this is acharya collage")
engine.runAndWait()
