# %% [markdown]
# # Break

# %%
for i in range(1,100):
    if i==6:
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # Continue

# %%
for i in range(0,10):
    if i==6:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 7
# 8
# 9

# %% [markdown]
# # Pass

# %%
for i in range(100):
    pass
