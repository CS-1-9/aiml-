# %%
dict={}
print(type(dict))
# Out:
# <class 'dict'>

# %%
my_dict={"name":"acharya",'age':56} 
print(my_dict)
my_dict['age']=19
print(my_dict)
my_dict["name"]= "chandan" 
print(my_dict)
my_dict["address"]="Bengaluru"
print(my_dict)
my_dict.copy()
print(my_dict)
my_dict.clear()
print(my_dict)
my_dict["name"]= "chandan" 
my_dict['age']=19
print(my_dict.keys())
print(my_dict)
my_dict.get("age")
# Out:
# {'name': 'acharya', 'age': 56}
# {'name': 'acharya', 'age': 19}
# {'name': 'chandan', 'age': 19}
# {'name': 'chandan', 'age': 19, 'address': 'Bengaluru'}
# {'name': 'chandan', 'age': 19, 'address': 'Bengaluru'}
# {}
# dict_keys(['name', 'age'])
# {'name': 'chandan', 'age': 19}
# 19

# %%
print(my_dict.items())
print(my_dict)
# Out:
# dict_items([('name', 'chandan'), ('age', 19)])
# {'name': 'chandan', 'age': 19}

# %%
my_dict = {"name":"acharya","age":25}
dict2 = {"name":"cs","age":19}
my_dict.update(dict2)
print(my_dict)
# Out:
# {'name': 'cs', 'age': 19}

# %%
company_user = {'user1':{'name':'J','age':'20','gender':'Male'},'user2':{'name':'Z','age':'22','gender':'Male'}}
print(company_user)
# Out:
# {'user1': {'name': 'J', 'age': '20', 'gender': 'Male'}, 'user2': {'name': 'Z', 'age': '22', 'gender': 'Male'}}
