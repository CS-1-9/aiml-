# %%
my_set = {11,22,33,44,55,66}
element = my_set.pop()
print(element)
print(my_set)
# Out:
# 33
# {66, 22, 55, 11, 44}

# %%
s1 = {4,5,6,7,8}
s2 = {3,5,6,7,4}
dif_set = s2.difference(s1)
print(dif_set)
union_set = s1.union(s2)
print(union_set)
# Out:
# {3}
# {3, 4, 5, 6, 7, 8}
