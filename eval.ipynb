# %%
s = eval("64+87")
print(s)
# Out:
# 151

# %%
x = eval(input("Enter the expression:"))
print(x)
# Out:
# 50

# %%
print(min(20,50,15))
print(max(20,50,15))
# Out:
# 15
# 50

# %%
x,y,z = 45,78,98
print(min(x,y,z))
# Out:
# 45
