# %%
t = ()
print(type(t))
# Out:
# <class 'tuple'>

# %%
my_data = (11,22,33,44,55,66,77,88,99)
print(my_data)
print(my_data[7]) #indexing
print(my_data[2:5])  #slicing
# Out:
# (11, 22, 33, 44, 55, 66, 77, 88, 99)
# 88
# (33, 44, 55)

# %%
print(my_data[4:-1])
print(my_data[:])
len(my_data)
# Out:
# (55, 66, 77, 88)
# (11, 22, 33, 44, 55, 66, 77, 88, 99)
# 9

# %%
my_data.count(55)
# Out:
# 1

# %%
my_data.index(66)
# Out:
# 5

# %%
print(my_data)
print(44 in my_data)
print(100 in my_data)
# Out:
# (11, 22, 33, 44, 55, 66, 77, 88, 99)
# True
# False

# %%
my_data2 = (33,44,66)
final_data = my_data + my_data2
print("Combine data",final_data)
# Out:
# Combine data (11, 22, 33, 44, 55, 66, 77, 88, 99, 33, 44, 66)

# %%
print(final_data*3)
# Out:
# (11, 22, 33, 44, 55, 66, 77, 88, 99, 33, 44, 66, 11, 22, 33, 44, 55, 66, 77, 88, 99, 33, 44, 66, 11, 22, 33, 44, 55, 66, 77, 88, 99, 33, 44, 66)

# %%
print(min(final_data)) #min
print(max(final_data)) #max
print(sum(final_data)) #sum
print(sorted(final_data)) #sorted
# Out:
# 11
# 99
# 638
# [11, 22, 33, 33, 44, 44, 55, 66, 66, 77, 88, 99]

# %%
#type conversion 
my_list = [1,2,3,4,5]
print(type(my_list))
print(my_list)
tu = tuple(my_list)
print(type(tu))
print(tu)
li = list(tu)
print(type(li))
print(li)
# Out:
# <class 'list'>
# [1, 2, 3, 4, 5]
# <class 'tuple'>
# (1, 2, 3, 4, 5)
# <class 'list'>
# [1, 2, 3, 4, 5]

# %%
tp=(11,22,33,44,55,66)
print(type(tp))
tp = list(tp)
print(tp)
tp[2] =100
print(tuple(tp))
# Out:
# <class 'tuple'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[95], line 3
#       1 tp=(11,22,33,44,55,66)
#       2 print(type(tp))
# ----> 3 tp = list(tp)
#       4 print(tp)
#       5 tp[2] =100
#
# TypeError: 'tuple' object is not callable
