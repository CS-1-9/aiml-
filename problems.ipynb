# %%
# write a program to take a single digit number from the keyboard and print is value in English word ?

n = int(input("Enter a single digit number:"))
if(n==1):
   print("One")
elif (n==2):
   print("Two")
elif (n==3):
   print("Three")
elif (n==4):
   print("Four")
elif (n==5):
   print("Five")
elif (n==6):
   print("Six")
elif (n==7):
   print("Seven")
elif (n==8):
   print("Eight")
elif (n==9):
   print("Nine")
elif (n==0):
   print("Zero")
else:
   print("Enter a valid number")
# Out:
# Five

# %%
#1 write a program to print multiplication of a given number using for loop.

n = int(input("Enter a number:"))
for i in range(1,11):
    print(f" {n} x {i} = {n * i} ")
# Out:
#  2 x 1 = 2
#  2 x 2 = 4
#  2 x 3 = 6
#  2 x 4 = 8
#  2 x 5 = 10
#  2 x 6 = 12
#  2 x 7 = 14
#  2 x 8 = 16
#  2 x 9 = 18
#  2 x 10 = 20

# %%
#2 to greet all the person names stored in a list 'l' and which starts with s.1 =["harry","sohan","sachin","rahul"]
l = [ "harry" , "sohan" , "sachin" , "rahul" ]
 
for name in l:
    if (name.startswith("s")):
        print("Hello",name)
# Out:
# Hello sohan
# Hello sachin

# %%
#3 attempt problem 1 using while loop.

n = int(input("Enter a number:"))
i = 1
while i<=10:
     print(f" {n} x {i} = {n * i}")
     i = i+1
     2
# Out:
#  2 x 1 = 2
#  2 x 2 = 4
#  2 x 3 = 6
#  2 x 4 = 8
#  2 x 5 = 10
#  2 x 6 = 12
#  2 x 7 = 14
#  2 x 8 = 16
#  2 x 9 = 18
#  2 x 10 = 20

# %%
#4 write a program to find whether a given number is prime or not.

n = int(input("Enter a number: "))
for i in range (2,n):
    if(n%i==0):
        print("Not prime")
        break
else:
        print("Prime")
# Out:
# Prime

# %%
#5 write a program to find the sum of first n natural numbers using while loop.

n = int(input("Enter a number: "))
pr = 1
for i in range(1,n+1):
    pr = pr*i
    print(i,pr)
print(f" Fact is {n} ,Iteration {i} ",pr)
# Out:
# 1 1
# 2 2
# 3 6
# 4 24
# 5 120
#  Fact is 5 ,Iteration 5  120

# %%
#6 write a program to calculate the factorial of a given number using for loop.

# %%
#7 write a program to print the following star pattern.
#    *
#   ***
#  *****  for n = 3

n = 1
for i in range(1,n+1):
    print("    *    ")
    print("   * *   ")
    print("  * * *   ")
# Out:
#     *
#    * *
#   * * *

# %%
#8 write a program to print the following star pattern.
# *
# **
# ***  for n = 3

n = 3 
for i in range(1,n+1):
    print("*"*i)
# Out:
# *
# **
# ***

# %%
#9 write a program to print the following star pattern.
# ***
# **   for n = 3 ***

# %%
#10 write a program to print multiplication table of n using for loops in reversed order.
