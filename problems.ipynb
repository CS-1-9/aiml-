# %%
#1 write a program to create a dictionary of hindi words with values as their english translation provide user with an option to look it up!

words = {
        "madad":"help",
        "aam":"mango",
        "pani":"water",
        "shanti":"peace"
        }
word = input("enter the word you want meaning of : ")
print(words[word])
# Out:
# water

# %%
set1 = {}
print(type(set1))
# Out:
# <class 'dict'>

# %%
set1 = {1,2,3,4}
set2 ={2,3,4,5}
print(set1,set2)
# Out:
# {1, 2, 3, 4} {2, 3, 4, 5}

# %%
set1.add(4)
print(set1)
# Out:
# {1, 2, 3, 4}

# %%
shop = {"mob","iphone","samsung","oneplus","book1","book2"}
print(shop)
shop.discard("book1")
print(shop)
shop.remove("iphone")
print(shop)
shop.discard("book1")
print(shop)
# Out:
# {'book2', 'samsung', 'iphone', 'oneplus', 'mob', 'book1'}
# {'book2', 'samsung', 'iphone', 'oneplus', 'mob'}
# {'book2', 'samsung', 'oneplus', 'mob'}
# {'book2', 'samsung', 'oneplus', 'mob'}

# %%
#2 write a program to input eigth numbers from the user and display all the unique numbers (once)
s = set()
n = int(input("enter the number"))
s.add(n)
n = int(input("enter the number"))
s.add(n)
n = int(input("enter the number"))
s.add(n)
n = int(input("enter the number"))
s.add(n)
n = int(input("enter the number"))
s.add(n)
n = int(input("enter the number"))
s.add(n)
n = int(input("enter the number"))
s.add(n)
n = int(input("enter the number"))
s.add(n)
print(s)
# Out:
# {1, 2, 3, 4, 5, 6, 8}

# %%
#3 can we have a set with 18(int) and '18'(str) as a value in it 
s = set()
s.add(18)
s.add('18')
print(s)
# Out:
# {18, '18'}

# %%
#4 what will be the length of following set s:s=set()s.add(20) s.add('20') #length of s after these operations

# %%
#5 s={} what is the type of 's'?
s ={}
print(type(s))
# Out:
# <class 'dict'>

# %%
#6 create an empty dictionary. Allow 4 friends to enter their favorite language as value and use key as their names.Assume that the names are unique
d = {}
name = input("Enter friend name")
lang = input("Enter language")
d.update({name:lang})
name = input("Enter friend name")
lang = input("Enter language")
d.update({name:lang})
name = input("Enter friend name")
lang = input("Enter language")
d.update({name:lang})
name = input("Enter friend name")
lang = input("Enter language")
d.update({name:lang})
print(d)
# Out:
# {'manju': 'telugu', 'naveen': 'kannada', 'chandan ': 'konkani', 'farhan ': 'urdu'}

# %%
#7 if the names of 2 friends are same;what will happen to the program in problem 6?
d = {}
name = input("Enter friend name")
lang = input("Enter language")
d.update({name:lang})
name = input("Enter friend name")
lang = input("Enter language")
d.update({name:lang})
name = input("Enter friend name")
lang = input("Enter language")
d.update({name:lang})
name = input("Enter friend name")
lang = input("Enter language")
d.update({name:lang})
print(d)
# Out:
# {'naveen ': 'kannada', 'manju': 'kannada', 'chandan ': 'konkani'}

# %%
#8 if languages of two friends are same;what will  happen to the program in problem 6?
d = {}
name = input("Enter friend name")
lang = input("Enter language")
d.update({name:lang})
name = input("Enter friend name")
lang = input("Enter language")
d.update({name:lang})
name = input("Enter friend name")
lang = input("Enter language")
d.update({name:lang})
name = input("Enter friend name")
lang = input("Enter language")
d.update({name:lang})
print(d)
# Out:
# {'naveen': 'kannada', 'manju': 'kannada', 'chandan': 'konkani', 'farhan': 'urdu'}

# %%
#9 can you change the values inside a list which is contained in set S?
# s ={8,7,12,"yogesh",[1,2]}
# Lists are unhashable and cannot be elements of a set.
# Use a tuple (which is hashable) instead:
s = {8, 7, 12, "yogesh", (1, 2)}
print(s)
# Out:
# {(1, 2), 7, 8, 12, 'yogesh'}
