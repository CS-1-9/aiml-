# %%
marks =[]
f1 = int (input("enter marks here:"))
marks.append(f1)
f2 = int (input("enter marks here:"))
marks.append(f2)
f3 = int (input("enter marks here:"))
marks.append(f3)
f4 = int (input("enter marks here:"))
marks.append(f4)
f5 = int (input("enter marks here:"))
marks.append(f5)
f6 = int (input("enter marks here:"))
marks.append(f6)

# %%
# write a program to store seven fruits in a list entered by the user
fruits =[]
for i in range(7):
    fruit = input(f"Enter fruit #{i+1}: ")
    fruits.append(fruit)
print("\nYour list of fruits:")
print(fruits)
# Out:
# Your list of fruits:
# ['apple', 'mango', 'grapes', 'pine apple', 'strawberry', 'orange', 'banana']

# %%
# accept marks of six students
marks = []
for idx in range(6):
    while True:
        try:
            m = float(input(f"Enter marks for student #{idx+1}: "))
            if 0 <= m <= 100:
                marks.append(m)
                break
            else:
                print("Please enter a value between 0 and 100.")
        except ValueError:
            print("Invalid input. Enter a numeric value.")
print("\nMarks entered:", marks)
print("Average:", sum(marks)/len(marks))
print("Highest:", max(marks))
print("Lowest:", min(marks))
# Out:
# Marks entered: [58.0, 98.0, 45.0, 65.0, 32.0, 23.0]
# Average: 53.5
# Highest: 98.0
# Lowest: 23.0
