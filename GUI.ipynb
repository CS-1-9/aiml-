# %%
from tkinter import *
y = Tk() # 
y.title("acharya GUI") # for title
y.geometry("500x400")
y.config(bg="orange")
def submit():
    print("Buttom clicked")
l1 = Label(y,text="Hello welcome to Acharya College")
l1.pack()
e1 = Entry(y,)
e1.place(x=200,y=100)
b1 = Button(y,text="click",command=submit)
b1.place(x=200,y=200)
y.mainloop() # the program will run until user wont close
# Out:
# Buttom clicked
